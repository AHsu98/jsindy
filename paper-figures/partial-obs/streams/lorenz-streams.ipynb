# %%
import os
import jax
jax.config.update('jax_enable_x64',True)
jax.config.update('jax_default_device',jax.devices()[1])
from pathlib import Path

from jsindy.sindy_model import JSINDyModel
from jsindy.trajectory_model import DataAdaptedRKHSInterpolant,CholDataAdaptedRKHSInterpolant
from jsindy.dynamics_model import FeatureLinearModel
from jsindy.optim import AlternatingActiveSetLMSolver, LMSettings,AnnealedAlternatingActiveSetLMSolver
from jsindy.optim.solvers.alt_active_set_lm_solver import pySindySparsifier
from pysindy import STLSQ,SSR,MIOSR
from exp.expdata import ExpData, LorenzExp
from exp.metrics import coeff_metrics, data_metrics
import pickle
import jax.numpy as jnp
import time
import matplotlib.pyplot as plt
from pysindy import EnsembleOptimizer
plt.style.use('ggplot')
plt.rcParams['font.family'] = 'serif'
import matplotlib as mpl
import dill
# mpl.rcParams.update({"text.usetex":True})

save_path = "data.pkl"

# %% [markdown]
# # Save Data/Model

# %%
exp_data = LorenzExp
initial_state = jnp.array([ -8,8,27.])
dt = 0.025
t_train = jnp.arange(0,10.01,dt)
noise_var = 0.1
# sigma^2 - var
true_sigma2 = noise_var
t0=0
t1=10.1
n_train = len(jnp.arange(t0,t1,dt))

n_colloc = 505
expdata = exp_data(
    initial_state=initial_state,
    t0=t0,
    t1=t1,
    dt = 0.01,
    dt_train=dt,
    noise= jnp.sqrt(true_sigma2),
    seed=29,
    n_colloc=n_colloc,
    one_rkey=True,
    feature_names=['x','y','z']
)

lorenz_sol = expdata.system_sol
t_train = expdata.t_train

# %%
true_sigma2 = 0.05
x_vals = jax.vmap(lorenz_sol.evaluate)(t_train)
x_train = x_vals + (
    jnp.sqrt(true_sigma2) * 
    jax.random.normal(jax.random.PRNGKey(32),(len(t_train),3))
)


num_obs_chain = 10
measurement_vecs = jnp.tile(
    jnp.repeat(jnp.eye(3),num_obs_chain,axis=0),(int(len(t_train)/(num_obs_chain * 3)+1),1))[:len(t_train)]

y_obs = jnp.sum(measurement_vecs*x_train,axis=1)

# %%
# plt.scatter(t_train[:100],jnp.argmax(measurement_vecs,axis=1)[:100],s = 5)

# %%
n_colloc = 500
trajectory_model = CholDataAdaptedRKHSInterpolant()
dynamics_model = FeatureLinearModel(reg_scaling = 1.)
optsettings = LMSettings(
    max_iter = 1000,
    show_progress=True,
    no_tqdm=False,
    min_alpha = 1e-16,
    init_alpha = 5.,
    print_every = 100,
)
data_weight =  1.
colloc_weight = 1e5
sparsifier = pySindySparsifier(
    STLSQ(threshold = 0.25,alpha = 0.01)
    )

# %%
optimizer = AnnealedAlternatingActiveSetLMSolver(
        beta_reg=0.001,
        solver_settings=optsettings,
        fixed_colloc_weight=colloc_weight,
        fixed_data_weight=data_weight,
        sparsifier = sparsifier
        )

model = JSINDyModel(
    trajectory_model=trajectory_model,
    dynamics_model=dynamics_model,
    optimizer=optimizer,
    feature_names=['x','y','z']
)

model.fit(
    t_train,
    t_colloc = None,
    w_colloc = None,
    partialobs_v = measurement_vecs,
    partialobs_y = y_obs,
)

metrics = {}

metrics["coeff_mets"]  = coeff_metrics(
    coeff_est = model.theta.T,
    coeff_true = expdata.true_coeff
)

metrics["data_mets"] = data_metrics(
    pred_sim = model.predict(expdata.x_true),
    true = expdata.x_dot
)
metrics['model_params'] = model.params

model.print()
# Out:
# {'show_progress': True, 'sigma2_est': Array(0.05181255, dtype=float64), 'data_weight': 1.0, 'colloc_weight': 100000.0}
# Solving for data_weight = 1.0, colloc_weight = 800.0 beta_reg = 0.008
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Iteration 0, loss = 1.111e+07, gradnorm = 6.701e+06, alpha = 7.5, improvement_ratio = 0.2081
# Iteration 1, loss = 9.789e+06, gradnorm = 6.54e+07, alpha = 68.34, improvement_ratio = 0.1191
# Iteration 2, loss = 9.017e+06, gradnorm = 7.998e+07, alpha = 123.0, improvement_ratio = 0.07888
# Iteration 3, loss = 6.299e+06, gradnorm = 1.08e+08, alpha = 100.0, improvement_ratio = 0.3017
# Iteration 4, loss = 4.92e+06, gradnorm = 7.739e+07, alpha = 150.0, improvement_ratio = 0.2192
# Iteration 5, loss = 6.961e+05, gradnorm = 6.944e+07, alpha = 83.33, improvement_ratio = 0.8593
# Iteration 100, loss = 159.2, gradnorm = 2.449e+04, alpha = 5.409, improvement_ratio = 0.7125
# Iteration 200, loss = 81.94, gradnorm = 6.324e+04, alpha = 4.507, improvement_ratio = 0.2838
# Iteration 300, loss = 18.0, gradnorm = 1.607e+04, alpha = 0.8735, improvement_ratio = 0.7307
# Iteration 398, loss = 9.543, gradnorm = 0.0002713, alpha = 502.2, improvement_ratio = 2.641e+03
# Solving for data_weight = 1.0, colloc_weight = 4000.0 beta_reg = 0.004
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Iteration 0, loss = 9.546, gradnorm = 116.3, alpha = 4.167, improvement_ratio = 1.0
# Iteration 1, loss = 9.546, gradnorm = 50.83, alpha = 3.472, improvement_ratio = 0.9999
# Iteration 2, loss = 9.546, gradnorm = 2.096, alpha = 2.894, improvement_ratio = 0.9999
# Iteration 3, loss = 9.546, gradnorm = 0.4329, alpha = 2.411, improvement_ratio = 1.0
# Iteration 4, loss = 9.546, gradnorm = 0.4316, alpha = 2.009, improvement_ratio = 1.0
# Iteration 5, loss = 9.546, gradnorm = 0.4023, alpha = 1.674, improvement_ratio = 1.0
# Line Search Failed!
# Final Iteration Results
# Iteration 51, loss = 9.546, gradnorm = 0.0012, alpha = 35.96, improvement_ratio = -6.477e+03
# Solving for data_weight = 1.0, colloc_weight = 20000.0 beta_reg = 0.002
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Iteration 0, loss = 9.546, gradnorm = 116.4, alpha = 4.167, improvement_ratio = 1.0
# Iteration 1, loss = 9.546, gradnorm = 18.36, alpha = 3.472, improvement_ratio = 0.9999
# Iteration 2, loss = 9.546, gradnorm = 0.4123, alpha = 2.894, improvement_ratio = 0.9999
# Iteration 3, loss = 9.546, gradnorm = 0.1349, alpha = 2.411, improvement_ratio = 1.0
# Iteration 4, loss = 9.546, gradnorm = 0.1184, alpha = 2.009, improvement_ratio = 1.0
# Iteration 5, loss = 9.546, gradnorm = 0.1001, alpha = 1.674, improvement_ratio = 1.0
# Line Search Failed!
# Final Iteration Results
# Iteration 48, loss = 9.546, gradnorm = 0.003252, alpha = 217.9, improvement_ratio = -3.903e+03
# Solving for data_weight = 1.0, colloc_weight = 100000.0 beta_reg = 0.001
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Iteration 0, loss = 9.546, gradnorm = 116.4, alpha = 4.167, improvement_ratio = 1.0
# Iteration 1, loss = 9.546, gradnorm = 4.938, alpha = 3.472, improvement_ratio = 0.9998
# Iteration 2, loss = 9.546, gradnorm = 0.04286, alpha = 2.894, improvement_ratio = 1.0
# Iteration 3, loss = 9.546, gradnorm = 0.03812, alpha = 2.411, improvement_ratio = 1.002
# Iteration 4, loss = 9.546, gradnorm = 0.04213, alpha = 2.009, improvement_ratio = 1.003
# Iteration 5, loss = 9.546, gradnorm = 0.01979, alpha = 1.674, improvement_ratio = 1.008
# Line Search Failed!
# Final Iteration Results
# Iteration 45, loss = 9.546, gradnorm = 0.007682, alpha = 6.482e+04, improvement_ratio = -2.837e+03
# Model after smooth warm start
# (x)' = 0.208 1 + -8.858 x + 9.128 y + 0.204 z + 0.082 x^2 + -0.093 x y + -0.034 x z + 0.020 y^2 + 0.024 y z + -0.008 z^2
# (y)' = -3.622 1 + 27.178 x + -0.344 y + 0.378 z + 0.006 x^2 + -0.008 x y + -0.980 x z + 0.003 y^2 + -0.015 y z + -0.009 z^2
# (z)' = -3.046 1 + 0.538 x + -0.388 y + -2.208 z + 0.071 x^2 + 0.935 x y + -0.013 x z + 0.019 y^2 + 0.012 y z + -0.015 z^2
# Alternating Activeset Sparsifier
# Line search Failed
# 8 active coeffs changed
# Line search Failed
# Active set stabilized
# Line search Failed
# (x)' = -9.987 x + 9.951 y
# (y)' = 28.104 x + -1.030 y + -1.003 x z
# (z)' = -0.606 1 + -2.642 z + 1.005 x y

# %%
expdata.print()
# Out:
# (x)' = -10.000 x + 10.000 y
# (y)' = 28.000 x + -1.000 y + -1.000 x z
# (z)' = -2.667 z + 1.000 x y

# %%
# t_grid = jnp.linspace(0,10,500)
# state_preds = model.predict_state(t_grid)
# true_states = jax.vmap(expdata.system_sol.evaluate)(t_grid)
# plt.figure(figsize=(12,8))
# for dim in range(3):
# 	plt.subplot(3,1,dim+1)
# 	obs_index = jnp.where(jnp.argmax(measurement_vecs,axis=1) == dim)
# 	plt.scatter(t_train[obs_index],y_obs[obs_index],label = 'Observations',s = 10,zorder = 10,c='red')
# 	plt.plot(t_grid,true_states[:,dim],label = 'True Trajectory',c='black')
# 	plt.plot(t_grid,state_preds[:,dim],label = 'State Estimates',c ='blue',alpha = 0.3,lw = 5)
# 	if dim ==0:
# 		plt.legend()
# 	plt.ylabel(f"$x_{dim+1}(t)$")
# plt.savefig("figures/stream10.pdf")
# plt.savefig("figures/stream10.png")

# %%
import diffrax
def model_ode(t,x,args = None):
    return model.predict(x)

dt0 = 0.005
stepsize_controller = diffrax.PIDController(rtol = 1e-8,atol =1e-8)
save_at = diffrax.SaveAt(dense=True)  # Save at regular intervals
pred_extend = diffrax.diffeqsolve(
	terms = diffrax.ODETerm(model_ode),
	solver = diffrax.Tsit5(),
	t0=t_train[-1],
	t1=20.,
	dt0=dt0,
	y0=expdata.system_sol.evaluate(t_train[-1]),
	saveat=save_at,
    stepsize_controller=stepsize_controller,
	max_steps = int(10*(t1-t0)/dt0)
)

from data.lorenz import lorenz_system

lorenz_args = (10.0, 28.0, 8.0/3.0)

true_extend = diffrax.diffeqsolve(
	terms = diffrax.ODETerm(lorenz_system),
    solver = diffrax.Tsit5(),
    t0=t_train[-1],
	t1=20.,
    dt0 = dt0,
    y0 = expdata.system_sol.evaluate(t_train[-1]),
    saveat = save_at,
    stepsize_controller=stepsize_controller,
	max_steps = int(10*(t1-t0)/dt),
	args = lorenz_args
)

# %%
t_fine = jnp.linspace(t_train[0],t_train[-1],1000)
x_true = jax.vmap(expdata.system_sol.evaluate)(t_fine)
x_pred = model.predict_state(t_fine)

t_extend = jnp.linspace(t_train[-1],18,500)

x_true_extend = jax.vmap(true_extend.evaluate)(t_extend)
x_sim_extend = jax.vmap(pred_extend.evaluate)(t_extend)

# %%
data = {
    "t_true": t_fine,
    "x_true": x_true,
    "x_pred": x_pred,
    "t_train": t_train,
    "x_train": x_train,
    "measurement_vecs": measurement_vecs,
    "t_extend": t_extend,
    "x_true_extend": x_true_extend,
    "x_sim_extend":x_sim_extend,
    "true_theta":expdata.true_coeff.T,
    "model": model
}

# _ = data.pop('model')

with open(save_path,'wb') as file:
    dill.dump(data,file)

# %%
os.path.getsize(save_path) / 1e6
# Out:
# 216.263569

# %% [markdown]
# # Load Data/Model

# %%
with open(save_path, 'rb') as file:
    data = dill.load(file)

t_fine = data["t_true"]
x_true = data["x_true"]
x_pred = data["x_pred"]

t_train = data["t_train"]
x_train = data["x_train"]
measurement_vecs = data['measurement_vecs']

y_obs = jnp.sum(measurement_vecs*x_train,axis=1)

t_extend = data["t_extend"]
x_true_extend = data["x_true_extend"]
x_sim_extend = data["x_sim_extend"]
true_theta = data['true_theta']
# model = data['model']

# %%
family='serif'
fig, ax = plt.subplots(3,1, figsize=(12,5),sharex=True,dpi=300)
ylabels = [r"$x_1(t)$", r"$x_2(t)$",r"$x_3(t)$"]



for dim in range(3):
    obs_index = jnp.where(jnp.argmax(measurement_vecs,axis=1) == dim)    
    ax[dim].scatter(
        t_train[obs_index], y_obs[obs_index],facecolors='black',edgecolors='red',lw=2., label='Observations',s=25,zorder=3)
    ax[dim].scatter(
        t_train[obs_index], y_obs[obs_index],c='black',s=2,zorder=4)
    
    ax[dim].plot(t_fine, x_true[:,dim], label='True Trajectory',c='black',zorder=2)
    ax[dim].plot(t_fine, x_pred[:,dim], label='State Estimates', linestyle='-',c='blue', alpha=0.4,lw=5,zorder=1)

    # extension 
    ax[dim].plot(t_extend,x_true_extend[:,dim], c='black', linestyle='--', label='True Unseen Trajectory')    

    ax[dim].plot(t_extend,x_sim_extend[:,dim],c='purple',alpha=0.4, lw=5,linestyle='-',label='Simulated Dynamics')

    ax[dim].grid(True)
    if dim==2:
        ax[dim].set_ylabel(ylabels[dim], size=15, family=family,labelpad=12)
    else:
        ax[dim].set_ylabel(ylabels[dim], size=15, family=family,)
    if dim==0:
        ax[dim].legend(prop={'family':family,'size':8},loc='upper right')
    if dim == 2:
        ax[dim].set_xlabel(r"$t$",size=15, family=family)
    
    # ax[dim].tick_params(axis='both', labelsize=15)

ax[2].set_xticks([0,5,10,15])
# plt.suptitle("Lorenz ", family=family,size=20)
# if savefigs:
plt.tight_layout()
plt.savefig(f"lorenz_streams.pdf")
plt.show()

# %%
mse = jnp.mean((x_true - x_pred)**2,axis=0)/jnp.var(x_true,axis=0)
mae = jnp.sum(jnp.abs(true_theta - model.theta)) / jnp.sum((jnp.abs(true_theta.flatten())))
# mse_sim = jnp.mean((x_true_extend - x_sim_extend)**2,axis=0)/jnp.var(x_true_extend,axis=0)

# %%
jnp.mean(mse).item(), mae.item()
# Out:
# (3.2399863826402904e-05, 0.015567207388991446)
