# %%
import os
import jax
jax.config.update('jax_enable_x64',True)
from pathlib import Path

from jsindy.sindy_model import JSINDyModel
from jsindy.trajectory_model import DataAdaptedRKHSInterpolant,CholDataAdaptedRKHSInterpolant
from jsindy.dynamics_model import FeatureLinearModel
from jsindy.optim import AlternatingActiveSetLMSolver, LMSettings
from jsindy.optim.solvers.alt_active_set_lm_solver import pySindySparsifier
from pysindy import STLSQ,SSR,MIOSR
from exp.expdata import ExpData, LorenzExp
from exp.metrics import coeff_metrics, data_metrics
import pickle
import dill
import jax.numpy as jnp
import time
import matplotlib.pyplot as plt
from pysindy import EnsembleOptimizer
plt.style.use('ggplot')
plt.rcParams['font.family'] = 'serif'
import matplotlib as mpl
# mpl.rcParams.update({"text.usetex":True})
save_path = 'data.pkl'
# Out:
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sympy2jax/sympy_module.py:291: UserWarning: `equinox.static_field` is deprecated in favour of `equinox.field(static=True)`
#   has_extra_funcs: bool = eqx.static_field()

# %% [markdown]
# # Run and Save Data/Model

# %%
initial_state = jnp.array([ -8,8,27.])
dt = 0.5
noise_var = 0.0
# sigma^2 - var
true_sigma2 = noise_var
t0=0
t1=10.1
n_train = len(jnp.arange(t0,t1,dt))

n_colloc = 505
expdata = LorenzExp(
    initial_state=initial_state,
    t0=t0,
    t1=t1,
    dt = 0.01,
    dt_train=dt,
    noise= jnp.sqrt(true_sigma2),
    seed=29,
    n_colloc=n_colloc,
    one_rkey=True,
    feature_names=['x','y','z']
)

# %%
trajectory_model = CholDataAdaptedRKHSInterpolant()
dynamics_model = FeatureLinearModel(reg_scaling = 1.)
optsettings = LMSettings(
    max_iter = 10000,
    show_progress=True,
    no_tqdm=False,
    min_alpha = 1e-16,
    init_alpha = 5.,
    print_every = 100,
)
data_weight =  1.
colloc_weight = 1e5
sparsifier = pySindySparsifier(
    STLSQ(threshold = 0.5,alpha = 0.01)
    )

optimizer = AlternatingActiveSetLMSolver(
        beta_reg=1e-3,
        solver_settings=optsettings,
        fixed_colloc_weight=colloc_weight,
        fixed_data_weight=data_weight,
        sparsifier = sparsifier
        )

model = JSINDyModel(
    trajectory_model=trajectory_model,
    dynamics_model=dynamics_model,
    optimizer=optimizer,
    feature_names=expdata.feature_names
)

model.fit(
    expdata.t_train,
    expdata.x_train,
    t_colloc = expdata.t_colloc,
    w_colloc = expdata.w_colloc
)

metrics = {}

metrics["coeff_mets"]  = coeff_metrics(
    coeff_est = model.theta.T,
    coeff_true = expdata.true_coeff
)

metrics["data_mets"] = data_metrics(
    pred_sim = model.predict(expdata.x_true),
    true = expdata.x_dot
)
metrics['model_params'] = model.params
# Out:
# {'show_progress': True, 'sigma2_est': Array(43.84970067, dtype=float64), 'data_weight': 1.0, 'colloc_weight': 100000.0}
# Warm Start
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Iteration 0, loss = 7.387e+08, gradnorm = 6.238e+08, alpha = 11.25, improvement_ratio = 0.4318
# Iteration 1, loss = 3.533e+08, gradnorm = 6.195e+09, alpha = 25.31, improvement_ratio = 0.5218
# Iteration 2, loss = 1.876e+08, gradnorm = 3.006e+09, alpha = 37.97, improvement_ratio = 0.4689
# Iteration 3, loss = 4.067e+07, gradnorm = 5.741e+09, alpha = 37.97, improvement_ratio = 0.7832
# Iteration 4, loss = 1.023e+07, gradnorm = 1.585e+09, alpha = 37.97, improvement_ratio = 0.7484
# Iteration 5, loss = 7.47e+06, gradnorm = 7.1e+08, alpha = 56.95, improvement_ratio = 0.2702
# Iteration 100, loss = 726.7, gradnorm = 2.702e+05, alpha = 506.2, improvement_ratio = 0.7146
# Iteration 200, loss = 489.8, gradnorm = 1.161e+06, alpha = 337.5, improvement_ratio = 0.289
# Iteration 300, loss = 306.5, gradnorm = 3.621e+05, alpha = 225.0, improvement_ratio = 0.5172
# Iteration 400, loss = 247.7, gradnorm = 2.853e+05, alpha = 150.0, improvement_ratio = 0.5218
# Iteration 500, loss = 221.4, gradnorm = 3.236e+05, alpha = 100.0, improvement_ratio = 0.517
# Iteration 600, loss = 199.8, gradnorm = 1.896e+05, alpha = 100.0, improvement_ratio = 0.7207
# Iteration 700, loss = 185.9, gradnorm = 1.459e+05, alpha = 100.0, improvement_ratio = 0.792
# Iteration 800, loss = 174.7, gradnorm = 1.695e+05, alpha = 69.44, improvement_ratio = 0.7271
# Iteration 900, loss = 163.6, gradnorm = 1.524e+05, alpha = 48.23, improvement_ratio = 0.745
# Iteration 1000, loss = 150.6, gradnorm = 1.471e+05, alpha = 33.49, improvement_ratio = 0.7614
# Iteration 1100, loss = 134.5, gradnorm = 1.541e+05, alpha = 23.26, improvement_ratio = 0.7889
# Iteration 1200, loss = 114.5, gradnorm = 2.072e+05, alpha = 16.15, improvement_ratio = 0.7834
# Iteration 1300, loss = 94.29, gradnorm = 2.568e+05, alpha = 13.46, improvement_ratio = 0.6498
# Iteration 1400, loss = 76.84, gradnorm = 8.263e+05, alpha = 13.46, improvement_ratio = 0.3161
# Iteration 1500, loss = 62.96, gradnorm = 6.852e+05, alpha = 23.26, improvement_ratio = 0.3742
# Iteration 1600, loss = 52.55, gradnorm = 2.45e+05, alpha = 9.346, improvement_ratio = 0.7227
# Iteration 1700, loss = 44.83, gradnorm = 7.242e+04, alpha = 5.409, improvement_ratio = 0.7165
# Iteration 1800, loss = 37.19, gradnorm = 1.014e+05, alpha = 4.507, improvement_ratio = 0.7777
# Iteration 1900, loss = 31.63, gradnorm = 1.854e+05, alpha = 4.507, improvement_ratio = 0.7448
# Iteration 2000, loss = 27.65, gradnorm = 2.57e+05, alpha = 4.507, improvement_ratio = 0.731
# Iteration 2100, loss = 24.83, gradnorm = 2.248e+05, alpha = 4.507, improvement_ratio = 0.7854
# Iteration 2200, loss = 22.55, gradnorm = 2.399e+05, alpha = 3.756, improvement_ratio = 0.7725
# Iteration 2300, loss = 20.69, gradnorm = 2.585e+05, alpha = 3.13, improvement_ratio = 0.7429
# Iteration 2400, loss = 19.23, gradnorm = 2.024e+05, alpha = 3.13, improvement_ratio = 0.788
# Iteration 2500, loss = 17.96, gradnorm = 2.305e+05, alpha = 2.608, improvement_ratio = 0.7262
# Iteration 2600, loss = 16.88, gradnorm = 1.834e+05, alpha = 2.608, improvement_ratio = 0.7625
# Iteration 2700, loss = 15.98, gradnorm = 1.476e+05, alpha = 2.608, improvement_ratio = 0.7917
# Iteration 2800, loss = 15.11, gradnorm = 1.67e+05, alpha = 2.174, improvement_ratio = 0.7216
# Iteration 2900, loss = 14.31, gradnorm = 1.286e+05, alpha = 2.174, improvement_ratio = 0.7477
# Iteration 3000, loss = 13.61, gradnorm = 9.726e+04, alpha = 2.174, improvement_ratio = 0.7625
# Iteration 3100, loss = 13.0, gradnorm = 7.101e+04, alpha = 2.174, improvement_ratio = 0.765
# Iteration 3200, loss = 12.45, gradnorm = 4.91e+04, alpha = 2.174, improvement_ratio = 0.7549
# Iteration 3300, loss = 11.96, gradnorm = 3.165e+04, alpha = 2.174, improvement_ratio = 0.7337
# Iteration 3400, loss = 11.52, gradnorm = 2.046e+04, alpha = 2.174, improvement_ratio = 0.7046
# Iteration 3500, loss = 11.11, gradnorm = 1.901e+04, alpha = 2.174, improvement_ratio = 0.6714
# Iteration 3600, loss = 10.75, gradnorm = 2.473e+04, alpha = 2.174, improvement_ratio = 0.6377
# Iteration 3700, loss = 10.41, gradnorm = 3.172e+04, alpha = 2.174, improvement_ratio = 0.6069
# Iteration 3800, loss = 10.1, gradnorm = 3.771e+04, alpha = 2.174, improvement_ratio = 0.5828
# Iteration 3900, loss = 9.813, gradnorm = 4.188e+04, alpha = 2.174, improvement_ratio = 0.5682
# Iteration 4000, loss = 9.542, gradnorm = 4.416e+04, alpha = 2.174, improvement_ratio = 0.5605
# Iteration 4100, loss = 9.288, gradnorm = 4.554e+04, alpha = 2.174, improvement_ratio = 0.5492
# Iteration 4200, loss = 9.048, gradnorm = 4.71e+04, alpha = 2.174, improvement_ratio = 0.5225
# Iteration 4300, loss = 8.819, gradnorm = 4.982e+04, alpha = 2.174, improvement_ratio = 0.478
# Iteration 4400, loss = 8.6, gradnorm = 5.349e+04, alpha = 2.174, improvement_ratio = 0.4262
# Iteration 4500, loss = 8.388, gradnorm = 5.644e+04, alpha = 2.174, improvement_ratio = 0.3888
# Iteration 4600, loss = 8.182, gradnorm = 5.5e+04, alpha = 2.174, improvement_ratio = 0.3981
# Iteration 4700, loss = 7.981, gradnorm = 4.736e+04, alpha = 2.174, improvement_ratio = 0.4808
# Iteration 4800, loss = 7.791, gradnorm = 3.776e+04, alpha = 2.174, improvement_ratio = 0.6078
# Iteration 4900, loss = 7.611, gradnorm = 3.028e+04, alpha = 2.174, improvement_ratio = 0.7159
# Iteration 5000, loss = 7.441, gradnorm = 2.511e+04, alpha = 2.174, improvement_ratio = 0.7861
# Iteration 5100, loss = 7.259, gradnorm = 3.024e+04, alpha = 1.811, improvement_ratio = 0.7454
# Iteration 5200, loss = 7.079, gradnorm = 2.568e+04, alpha = 1.811, improvement_ratio = 0.7898
# Iteration 5300, loss = 6.887, gradnorm = 3.106e+04, alpha = 1.509, improvement_ratio = 0.7328
# Iteration 5400, loss = 6.699, gradnorm = 2.577e+04, alpha = 1.509, improvement_ratio = 0.7737
# Iteration 5500, loss = 6.512, gradnorm = 2.994e+04, alpha = 1.258, improvement_ratio = 0.7155
# Iteration 5600, loss = 6.314, gradnorm = 2.265e+04, alpha = 1.258, improvement_ratio = 0.7721
# Iteration 5700, loss = 6.11, gradnorm = 2.274e+04, alpha = 1.048, improvement_ratio = 0.7399
# Iteration 5800, loss = 5.891, gradnorm = 2.032e+04, alpha = 0.8735, improvement_ratio = 0.7252
# Iteration 5900, loss = 5.64, gradnorm = 1.623e+04, alpha = 0.728, improvement_ratio = 0.7303
# Iteration 6000, loss = 5.349, gradnorm = 1.416e+04, alpha = 0.6066, improvement_ratio = 0.7376
# Iteration 6100, loss = 5.021, gradnorm = 1.562e+04, alpha = 0.5055, improvement_ratio = 0.7112
# Iteration 6200, loss = 4.654, gradnorm = 1.395e+04, alpha = 0.5055, improvement_ratio = 0.7249
# Iteration 6300, loss = 4.294, gradnorm = 1.506e+04, alpha = 0.5055, improvement_ratio = 0.6405
# Iteration 6400, loss = 3.917, gradnorm = 2.336e+04, alpha = 0.5055, improvement_ratio = 0.4234
# Iteration 6500, loss = 3.445, gradnorm = 5.744e+04, alpha = 0.5055, improvement_ratio = 0.2541
# Iteration 6600, loss = 2.812, gradnorm = 4.337e+04, alpha = 0.5055, improvement_ratio = 0.3871
# Iteration 6700, loss = 2.276, gradnorm = 2.898e+04, alpha = 0.5055, improvement_ratio = 0.4756
# Iteration 6800, loss = 1.871, gradnorm = 2.734e+04, alpha = 0.5055, improvement_ratio = 0.4828
# Iteration 6900, loss = 1.563, gradnorm = 2.456e+04, alpha = 0.5055, improvement_ratio = 0.4884
# Iteration 7000, loss = 1.334, gradnorm = 1.937e+04, alpha = 0.5055, improvement_ratio = 0.524
# Iteration 7100, loss = 1.165, gradnorm = 1.496e+04, alpha = 0.5055, improvement_ratio = 0.5535
# Iteration 7200, loss = 1.04, gradnorm = 1.155e+04, alpha = 0.5055, improvement_ratio = 0.573
# Iteration 7300, loss = 0.9477, gradnorm = 8.36e+03, alpha = 0.5055, improvement_ratio = 0.6176
# Iteration 7400, loss = 0.8787, gradnorm = 5.492e+03, alpha = 0.5055, improvement_ratio = 0.7026
# Iteration 7500, loss = 0.828, gradnorm = 3.426e+03, alpha = 0.5055, improvement_ratio = 0.7949
# Iteration 7600, loss = 0.7853, gradnorm = 4.083e+03, alpha = 0.3511, improvement_ratio = 0.702
# Iteration 7700, loss = 0.7502, gradnorm = 3.191e+03, alpha = 0.2926, improvement_ratio = 0.72
# Iteration 7800, loss = 0.7244, gradnorm = 2.572e+03, alpha = 0.2438, improvement_ratio = 0.7261
# Iteration 7900, loss = 0.7073, gradnorm = 1.717e+03, alpha = 0.2438, improvement_ratio = 0.7941
# Iteration 8000, loss = 0.6958, gradnorm = 2.279e+03, alpha = 0.2032, improvement_ratio = 0.6874
# Iteration 8100, loss = 0.6876, gradnorm = 3.392e+03, alpha = 0.2032, improvement_ratio = 0.5334
# Iteration 8200, loss = 0.6795, gradnorm = 8.654e+03, alpha = 0.2032, improvement_ratio = 0.2134
# Iteration 8300, loss = 0.6696, gradnorm = 9.407e+03, alpha = 0.3511, improvement_ratio = 0.2202
# Iteration 8400, loss = 0.6574, gradnorm = 1.074e+04, alpha = 0.5055, improvement_ratio = 0.2208
# Iteration 8500, loss = 0.6421, gradnorm = 1.059e+04, alpha = 0.6066, improvement_ratio = 0.2456
# Iteration 8600, loss = 0.6235, gradnorm = 1.185e+04, alpha = 0.6066, improvement_ratio = 0.2167
# Iteration 8700, loss = 0.6029, gradnorm = 1.033e+04, alpha = 0.6066, improvement_ratio = 0.2461
# Iteration 8800, loss = 0.5834, gradnorm = 6.939e+03, alpha = 0.6066, improvement_ratio = 0.3321
# Iteration 8900, loss = 0.5675, gradnorm = 4.079e+03, alpha = 0.6066, improvement_ratio = 0.4552
# Iteration 9000, loss = 0.5556, gradnorm = 2.312e+03, alpha = 0.6066, improvement_ratio = 0.5945
# Iteration 9100, loss = 0.5469, gradnorm = 1.331e+03, alpha = 0.6066, improvement_ratio = 0.7246
# Iteration 9200, loss = 0.5403, gradnorm = 1.114e+03, alpha = 0.5055, improvement_ratio = 0.74
# Iteration 9300, loss = 0.5348, gradnorm = 868.4, alpha = 0.4213, improvement_ratio = 0.7805
# Iteration 9400, loss = 0.5301, gradnorm = 867.2, alpha = 0.2926, improvement_ratio = 0.7645
# Iteration 9500, loss = 0.5266, gradnorm = 1.013e+03, alpha = 0.1693, improvement_ratio = 0.717
# Iteration 9600, loss = 0.5243, gradnorm = 978.5, alpha = 0.08165, improvement_ratio = 0.7367
# Iteration 9700, loss = 0.5235, gradnorm = 313.7, alpha = 0.01899, improvement_ratio = 0.7819
# Iteration 9800, loss = 0.5234, gradnorm = 0.03397, alpha = 0.02734, improvement_ratio = 0.2033
# Iteration 9855, loss = 0.5234, gradnorm = 0.06562, alpha = 0.08165, improvement_ratio = 0.2168
# Model after smooth warm start
# (x)' = 1.840 1 + -5.631 x + 6.950 y + -0.367 z + 0.149 x^2 + -0.206 x y + -0.208 x z + 0.050 y^2 + 0.165 y z + 0.015 z^2
# (y)' = 2.108 1 + 14.646 x + 6.843 y + -1.111 z + -0.991 x^2 + 1.121 x y + -0.572 x z + -0.339 y^2 + -0.234 y z + 0.066 z^2
# (z)' = -0.233 1 + 3.029 x + -2.247 y + -2.123 z + 0.139 x^2 + 0.778 x y + -0.086 x z + 0.105 y^2 + 0.068 y z + -0.029 z^2
# Alternating Activeset Sparsifier
# 10 active coeffs changed
# Line search Failed
# 5 active coeffs changed
# Line search Failed
# Active set stabilized
# Line search Failed

# %%
t_grid = jnp.linspace(t0,10,1000)
state_preds = model.predict_state(t_grid)
true_states = jax.vmap(expdata.system_sol.evaluate)(t_grid)

# %% [markdown]
# ## simulate on unseen data

# %%
import diffrax
from data.lorenz import lorenz_system


true_system = jax.jit(lorenz_system)

jit_lor_pred = jax.jit(model.predict)


def learned_system(t,x,args):
    return jit_lor_pred(x)



def simulate_sol(y0,system, t0=expdata.t0,t1=expdata.t1,dt=expdata.dt,t_eval = expdata.t_true, args = None):
    term = diffrax.ODETerm(system)
    solver = diffrax.Tsit5()

    save_at = diffrax.SaveAt(dense=True)
    sol = diffrax.diffeqsolve(
        term,
        solver,
        t0 = t0,
        t1=t1,
        dt0=dt,
        y0=y0,
        args = args,
        saveat=save_at,
        max_steps=int(10*(t1-t0)/dt)
    )

    return jax.vmap(sol.evaluate)(t_eval)

# %%
lorenz_args = (expdata.sigma,expdata.rho, expdata.beta)
x_train = expdata.x_train
t_new = jnp.linspace(0,12, 1010)
t_extend = t_new + t_grid[-1]

x_true_extend = simulate_sol(x_train[-1],system=true_system,t0=t_new[0],t1=t_new[-1], t_eval=t_new, args=lorenz_args)
x_sim_extend = simulate_sol(x_train[-1],system=learned_system,t0=t_new[0],t1=t_new[-1], t_eval=t_new,)

# %% [markdown]
# ## Save data

# %%
data = {
    "t_true": t_grid,
    "x_true": true_states,
    "x_pred": state_preds,
    "t_train": expdata.t_train,
    "x_train": expdata.x_train,
    "t_extend": t_extend,
    "x_true_extend": x_true_extend,
    "x_sim_extend":x_sim_extend,
    "true_theta":expdata.true_coeff.T,
    "model": model
}

# _ = data.pop("model")

with open(save_path,'wb') as file:
    dill.dump(data,file)

# %%
os.path.getsize(save_path) / 1e6
# Out:
# 221.146781

# %% [markdown]
# # Load Data/Model

# %%
with open(save_path, 'rb') as file:
    data = dill.load(file)

t_true = data["t_true"]
x_true = data["x_true"]
x_pred = data["x_pred"]

t_train = data["t_train"]
x_train = data["x_train"]

t_extend = data["t_extend"]
x_true_extend = data["x_true_extend"]
x_sim_extend = data["x_sim_extend"]
true_theta = data['true_theta']

model = data["model"]

# %%
fig, axs  = plt.subplots(3,1, figsize=(12,5),sharex=True,dpi=300)

axs = axs.flatten()
lw=1.5

y_labels = [r"$x_1(t)$", r"$x_2(t)$", r"$x_3(t)$"]
for idx, ax in enumerate(axs):
    ax.scatter(t_train,x_train[:,idx],zorder = 3, facecolors='black', edgecolors='red', label="Observations", s=18,lw=1.5)
    ax.plot(t_true,x_true[:,idx],label = 'True Trajectory',c='black',zorder=2)
    ax.plot(t_true,x_pred[:,idx],label='State Estimation', linestyle='-',c='blue', alpha=0.4,lw=7,zorder=1)

    # extended
    
    ax.plot(t_extend, x_true_extend[:,idx],c='black', linestyle='--', label='True Unseen Trajectory')
    ax.plot(t_extend, x_sim_extend[:,idx],c='purple',alpha=0.4, lw=7,linestyle='-',label='Simulated Dynamics')

    if idx> 1:
        ax.set_ylabel(y_labels[idx],size=15, rotation = 90,labelpad=13)
    else:
        ax.set_ylabel(y_labels[idx],size=15, rotation = 90)

    if idx == 0:
        ax.legend(loc ='upper right',prop={'size':8})
    if idx == len(y_labels) - 1:
        ax.set_xlabel(r"$t$", size=15)

plt.tight_layout()
plt.savefig("scarce_lorenz.pdf")
plt.show()

# %% [markdown]
# # Metrics

# %% [markdown]
# - rmse of stuff
# - mean aboslute error of coeff

# %%
mse = jnp.linalg.norm(x_true - x_pred)**2 / jnp.var(x_true)
mae_coeff = jnp.sum(jnp.abs(true_theta - model.theta)) / len(true_theta.flatten())
# Out:
# Array(0.00349962, dtype=float64)

# %%
cum_mse = [
    jnp.linalg.norm(x_true_extend[:i] - x_sim_extend[:i])**2 / jnp.var(x_true_extend[:i])
    for i in range(1,len(x_true_extend))
]

# %%
cutoff = 400
plt.plot(t_extend[1:cutoff+1],cum_mse[:cutoff])

# %%
cum_mse[100]
# Out:
# Array(0.00104714, dtype=float64)

# %%
len(cum_mse)
# Out:
# 1009
