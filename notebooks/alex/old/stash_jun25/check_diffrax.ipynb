# %%
import jax
import jax.numpy as jnp
import diffrax

# %%
def vector_field(t, y, args):
    A = args
    return A @ y

term = diffrax.ODETerm(vector_field)
t0 = 0
t1 = 1
y0 = jnp.array([1., 1.])
A = jnp.array([[0., 1.], [-1., 0.]])
dt0 = None
solver = diffrax.Tsit5()
stepsize_controller = diffrax.PIDController(rtol=1e-8, atol=1e-8)
args = A

sol = diffrax.diffeqsolve(
        term,
        solver,
        t0,
        t1,
        dt0,
        y0,
        stepsize_controller=stepsize_controller,
        args=args
)

print(sol.ys)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 8
#       6 t0 = 0
#       7 t1 = 1
# ----> 8 y0 = jnp.array([1., 1.])
#       9 A = jnp.array([[0., 1.], [-1., 0.]])
#      10 dt0 = None
#
# File ~/miniconda3/envs/jsindy/lib/python3.13/site-packages/jax/_src/numpy/lax_numpy.py:5548, in array(object, dtype, copy, order, ndmin, device)
#    5546 else:
#    5547   raise TypeError(f"Unexpected input type for array: {type(object)}")
# -> 5548 out_array: Array = lax_internal._convert_element_type(
#    5549     out, dtype, weak_type=weak_type, sharding=sharding)
#    5550 if ndmin > np.ndim(out_array):
#    5551   out_array = lax.expand_dims(out_array, range(ndmin - np.ndim(out_array)))
#
# File ~/miniconda3/envs/jsindy/lib/python3.13/site-packages/jax/_src/lax/lax.py:1727, in _convert_element_type(operand, new_dtype, weak_type, sharding, warn_on_complex_to_real_cast)
#    1725   return operand
#    1726 else:
# -> 1727   return convert_element_type_p.bind(
#    1728       operand, new_dtype=new_dtype, weak_type=bool(weak_type),
#    1729       sharding=sharding)
#
# File ~/miniconda3/envs/jsindy/lib/python3.13/site-packages/jax/_src/core.py:496, in Primitive.bind(self, *args, **params)
#     494 def bind(self, *args, **params):
#     495   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 496   return self._true_bind(*args, **params)
#
# File ~/miniconda3/envs/jsindy/lib/python3.13/site-packages/jax/_src/core.py:512, in Primitive._true_bind(self, *args, **params)
#     510 trace_ctx.set_trace(eval_trace)
#     511 try:
# --> 512   return self.bind_with_trace(prev_trace, args, params)
#     513 finally:
#     514   trace_ctx.set_trace(prev_trace)
#
# File ~/miniconda3/envs/jsindy/lib/python3.13/site-packages/jax/_src/lax/lax.py:4875, in _convert_element_type_bind_with_trace(trace, args, params)
#    4873 def _convert_element_type_bind_with_trace(trace, args, params):
#    4874   sharding = params['sharding']
# -> 4875   operand = core.Primitive.bind_with_trace(convert_element_type_p, trace, args, params)
#    4876   if sharding is not None and sharding._is_concrete:
#    4877     with core.set_current_trace(trace):
#
# File ~/miniconda3/envs/jsindy/lib/python3.13/site-packages/jax/_src/core.py:517, in Primitive.bind_with_trace(self, trace, args, params)
#     516 def bind_with_trace(self, trace, args, params):
# --> 517   return trace.process_primitive(self, args, params)
#
# File ~/miniconda3/envs/jsindy/lib/python3.13/site-packages/jax/_src/core.py:1017, in EvalTrace.process_primitive(self, primitive, args, params)
#    1015 args = map(full_lower, args)
#    1016 check_eval_args(args)
# -> 1017 return primitive.impl(*args, **params)
#
# File ~/miniconda3/envs/jsindy/lib/python3.13/site-packages/jax/_src/dispatch.py:89, in apply_primitive(prim, *args, **params)
#      87 prev = lib.jax_jit.swap_thread_local_state_disable_jit(False)
#      88 try:
# ---> 89   outs = fun(*args)
#      90 finally:
#      91   lib.jax_jit.swap_thread_local_state_disable_jit(prev)
#
#     [... skipping hidden 5 frame]
#
# File ~/miniconda3/envs/jsindy/lib/python3.13/site-packages/jax/_src/interpreters/pxla.py:1298, in ExecuteReplicated.__call__(self, *args)
#    1296   self._handle_token_bufs(result_token_bufs, sharded_runtime_token)
#    1297 else:
# -> 1298   results = self.xla_executable.execute_sharded(input_bufs)
#    1300 if dispatch.needs_check_special():
#    1301   out_arrays = results.disassemble_into_single_device_arrays()
#
# RuntimeError: Bad StatusOr access: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
