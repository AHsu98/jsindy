# %%
import jax
jax.config.update('jax_enable_x64',True)
jax.config.update('jax_default_device',jax.devices()[4])
from jax.random import PRNGKey
from tqdm.auto import tqdm
from exp.expdata import LorenzExp
import jax.numpy as jnp
import matplotlib.pyplot as plt
plt.style.use("ggplot")

from jsindy.sindy_model import JSINDyModel
from jsindy.trajectory_model import DataAdaptedRKHSInterpolant,CholDataAdaptedRKHSInterpolant
from jsindy.dynamics_model import FeatureLinearModel
from jsindy.optim import AlternatingActiveSetLMSolver, LMSettings
from jsindy.optim.solvers.alt_active_set_lm_solver import pySindySparsifier
from pysindy import STLSQ,SSR,MIOSR


seed = 1234
rkey = PRNGKey(seed)

# %%
x0 = jnp.array([-8, 8, 27.])
dt = 0.01
t0=0
t1=10.1
n_colloc = 1000
expdata = LorenzExp(
    dt = dt,
    initial_state=x0,
    feature_names=['x','y','z'],
    t0=t0,
    t1=t1,
    n_colloc=n_colloc
)

# %%
tEndL = jnp.arange(4.0, 11.0, 1.0)
epsL = jnp.arange(0.025, 0.401, 0.025)

tEndL, epsL
# Out:
# (Array([ 4.,  5.,  6.,  7.,  8.,  9., 10.], dtype=float64),
#  Array([0.025, 0.05 , 0.075, 0.1  , 0.125, 0.15 , 0.175, 0.2  , 0.225,
#         0.25 , 0.275, 0.3  , 0.325, 0.35 , 0.375, 0.4  ], dtype=float64))

# %%
t_true = expdata.t_true
X_true = expdata.x_true

# %%
# expdata.w_colloc

# %%
cutoff = 1
signal_power = jnp.std(X_true)
for t_end in tqdm(tEndL[:cutoff],leave=True):
    for noise_ratio in tqdm(epsL[:cutoff], leave=False):
        t_end_idx = int(t_end // dt)
        X_train = X_true[:t_end_idx]
        t_train = t_true[:t_end_idx]

        eps = noise_ratio*signal_power


        noise = eps*jax.random.normal(rkey, X_train.shape)

        X_train += noise

        trajectory_model = CholDataAdaptedRKHSInterpolant()
        dynamics_model = FeatureLinearModel(reg_scaling = 1.)
        optsettings = LMSettings(
            max_iter = 2000,
            show_progress=True,
            no_tqdm=False,
            min_alpha = 1e-16,
            init_alpha = 5.,
            print_every = 100,
        )
        data_weight =  100
        colloc_weight = 1e5
        sparsifier = pySindySparsifier(
            STLSQ(threshold = 0.5,alpha = 0.1)
            )
        # sparsifier = pySindySparsifier(EnsembleOptimizer(STLSQ(threshold = 0.5,alpha = 0.1),bagging=True,n_models = 100))

        # sparsifier = pySindySparsifier(
        #     MIOSR(target_sparsity = 7,alpha = 0.1)
        #     )


        optimizer = AlternatingActiveSetLMSolver(
                beta_reg=1e-3,
                solver_settings=optsettings,
                fixed_colloc_weight=colloc_weight,
                fixed_data_weight=data_weight,
                sparsifier = sparsifier
                )

        model = JSINDyModel(
            trajectory_model=trajectory_model,
            dynamics_model=dynamics_model,
            optimizer=optimizer,
            feature_names=expdata.feature_names
        )

        model.fit(t_train, X_train)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/3000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# {'show_progress': True, 'sigma2_est': Array(0.10929162, dtype=float64), 'data_weight': 100, 'colloc_weight': 100000.0}
# Warm Start
#   0%|          | 0/2000 [00:00<?, ?it/s]
# Iteration 0, loss = 8.195e+03, gradnorm = 3.953e+07, alpha = 4.167, improvement_ratio = 0.9998
# Iteration 1, loss = 6.386e+03, gradnorm = 1.339e+06, alpha = 3.472, improvement_ratio = 0.984
# Iteration 2, loss = 6.345e+03, gradnorm = 5.125e+05, alpha = 2.894, improvement_ratio = 0.9513
# Iteration 3, loss = 6.338e+03, gradnorm = 1.085e+05, alpha = 2.411, improvement_ratio = 0.9501
# Iteration 4, loss = 6.336e+03, gradnorm = 3.747e+04, alpha = 2.009, improvement_ratio = 0.9664
# Iteration 5, loss = 6.334e+03, gradnorm = 1.337e+04, alpha = 1.674, improvement_ratio = 0.9767
# Line Search Failed!
# Final Iteration Results
# Iteration 59, loss = 6.333e+03, gradnorm = 0.01429, alpha = 3.99e+05, improvement_ratio = -inf
# Model after smooth warm start
# (x)' = -1.940 1 + -9.380 x + 9.690 y + 0.056 z + -0.022 x^2 + 0.017 x y + -0.015 x z + 0.007 y z + 0.001 z^2
# (y)' = 1.808 1 + 27.460 x + -0.773 y + -0.165 z + -0.035 x^2 + 0.025 x y + -0.985 x z + -0.002 y^2 + -0.006 y z + 0.005 z^2
# (z)' = -0.187 1 + 0.244 x + -0.094 y + -2.737 z + -0.030 x^2 + 1.021 x y + -0.007 x z + 0.001 y z + 0.004 z^2
# Alternating Activeset Sparsifier
# Line search Failed
# 9 active coeffs changed
# Line search Failed
# Active set stabilized
# Line search Failed

# %%
model.print()
# Out:
# (x)' = -9.956 x + 10.004 y
# (y)' = 27.797 x + -0.979 y + -0.994 x z
# (z)' = -2.669 z + 1.002 x y

# %%
jnp.log10(jnp.linalg.norm(model.theta.T - expdata.true_coeff)/jnp.linalg.norm(expdata.true_coeff))
# Out:
# Array(-2.17944597, dtype=float64)

# %%
X_pred = model.predict_state(t_train)
dx_pred = model.traj_model.derivative(t_train,model.z,diff_order = 1)
true_vals = jax.vmap(expdata.system_sol.evaluate)(t_train)

plt.figure(figsize=(10,4))
for i in range(3):
    plt.subplot(3,1,i+1)
    plt.plot(t_train,X_pred[:,i],lw = 5,alpha = 0.4,c='blue')
    plt.scatter(t_train,X_train[:,i])
    plt.plot(t_train,true_vals[:,i])
plt.show()

# %%
X_pred = model.predict_state(expdata.t_colloc)
dx_pred = model.traj_model.derivative(expdata.t_colloc,model.z,diff_order = 1)

true_vals = jax.vmap(expdata.system_sol.evaluate)(expdata.t_colloc)
true_dx = jax.vmap(jax.jacfwd(expdata.system_sol.evaluate))(expdata.t_colloc)


plt.figure(figsize=(10,4))
for i in range(3):
    plt.subplot(3,1,i+1)
    plt.plot(expdata.t_colloc,X_pred[:,i] - true_vals[:,i])
    # plt.scatter(t_train,X_train[:,i])
    # plt.plot(t_train,true_vals[:,i])
plt.tight_layout()
plt.show()

plt.figure(figsize=(10,4))
for i in range(3):
    plt.subplot(3,1,i+1)
    plt.plot(expdata.t_colloc,dx_pred[:,i] - true_dx[:,i])
    # plt.scatter(t_train,X_train[:,i])
    # plt.plot(t_train,true_vals[:,i])
plt.tight_layout()
plt.show()

# %%
jnp.linalg.norm(X_pred - true_vals)/jnp.linalg.norm(true_vals)
# Out:
# Array(0.00325256, dtype=float64)

# %%
jnp.linalg.norm(dx_pred - true_dx)/jnp.linalg.norm(true_dx)
# Out:
# Array(0.01165521, dtype=float64)

# %%
import numpy as np
from pysindy import PolynomialLibrary,STLSQ

opt = STLSQ(alpha = 0.1,threshold=0.5)
lib = PolynomialLibrary()

state_est = np.array(X_pred)
dx_est = np.array(dx_pred)

A = lib.fit_transform(state_est)
opt.fit(A,dx_est)
model.print(opt.coef_.T)
# Out:
# (x)' = -9.911 x + 9.968 y
# (y)' = 27.733 x + -0.953 y + -0.993 x z
# (z)' = -2.668 z + 1.002 x y

# %%
jnp.log10(jnp.linalg.norm(jnp.array(opt.coef_) - expdata.true_coeff)/jnp.linalg.norm(expdata.true_coeff))
# Out:
# Array(-2.04068802, dtype=float64)

# %%
model.print()
expdata.print()
# Out:
# (x)' = -10.787 x + 10.633 y
# (y)' = 25.000 x + -0.928 x z
# (z)' = 5.387 1 + -2.972 z + 1.011 x y
# (x)' = -10.000 x + 10.000 y
# (y)' = 28.000 x + -1.000 y + -1.000 x z
# (z)' = -2.667 z + 1.000 x y

# %%
jnp.log10(jnp.linalg.norm(expdata.true_coeff - model.theta.T)/jnp.linalg.norm(expdata.true_coeff))
# Out:
# Array(-0.79864209, dtype=float64)

# %%
import numpy as np

z = model.traj_model.get_fitted_params(t_train,X_train,0.1/(eps**2))
state_est = np.array(model.traj_model(t_train,z))

dx_est = np.array(model.traj_model.derivative(t_train,z,1))

# %%
from pysindy import PolynomialLibrary,STLSQ

opt = STLSQ(alpha = 0.1,threshold=0.5)
lib = PolynomialLibrary()

A = lib.fit_transform(state_est)
opt.fit(A,dx_est)
# Out:
# STLSQ(alpha=0.1, threshold=0.5)

# %%
model.print(opt.coef_.T)
# Out:
# (x)' = -0.595 1 + -9.644 x + 9.749 y
# (y)' = 25.142 x + -0.939 x z
# (z)' = -0.733 1 + -2.613 z + 0.998 x y

# %%
jnp.log10(jnp.linalg.norm(opt.coef_ - expdata.true_coeff)/jnp.linalg.norm(expdata.true_coeff))
# Out:
# Array(-0.99319599, dtype=float64)

# %%
model.traj_model.get_fitted_params?
# Out:
# Signature: model.traj_model.get_fitted_params(t, obs, lam=0.0001)
# Docstring: <no docstring>
# File:      /mnt/share/homes/owlx/sindy_work/jsindy/jsindy/trajectory_model.py
# Type:      method

# %%
print(model)
# Out:
# --------Trajectory Model--------
#
# MLE Adapted Cholesky Parametrized RKHS Trajectory Model
# kernel: 181.229 + 88.51Matern(5,0.16)
# derivative_orders: (0, 1)
# nugget: 1e-08
#
#
# --------Feature Library---------
# degree: 2
# include_bias: True
# include_interaction: True
# interaction_only: False
# order: C
#
# --------Optimizer Setup--------
#
# Alternating Active Set Optimizer
# beta_reg: 0.001,
# sparsifier: STLSQ(alpha=1.0, threshold=0.75)
# data_weight: 100
# colloc_weight: 1000

# %%
time_idices = [400, 500, 600, 700,800,900,1000]

# %%
true_vals = jax.vmap(expdata.system_sol.evaluate)(t_train)
for idx in range(3):
    plt.plot(t_train, X_pred)
    plt.scatter(t_train, X_train[:,idx])
    plt.plot(t_train,true_vals[:,i])
    plt.show()

# %%
fig, axs = plt.subplots(3,1,figsize=(15,5),sharex=True)
axs = axs.flatten()
for idx, ax in enumerate(axs):
    ax.plot(t_true, X_true[:,idx])
    for trial_time in tEndL:
        ax.axvline(trial_time)
    if idx == len(axs)-1:
        ax.set_xlabel(r"$t$", size=20)
plt.show()

# %% [markdown]
# converted code

# %%
yeehaw
"""
lorenz_sindy_mwe.py
Minimal Working Example (MWE) ported from the MATLAB script to Python.

Requirements:
    pip install numpy scipy scikit-learn tqdm

Runs:
    python lorenz_sindy_mwe.py
"""
import numpy as np
from scipy.integrate import solve_ivp
from sklearn.linear_model import Lasso
from tqdm import trange
import os

# -----------------------
# Problem / experiment parameters
# -----------------------
epsL = np.arange(0.025, 0.401, 0.025)   # noise ratios
tEndL = np.arange(4.0, 11.0, 1.0)       # simulation times: 4..10
nTest1 = 20    # SINDy repeats
nTest2 = 64    # Ensemble repeats

# SINDy / ensemble hyperparams
lambda_alpha = 0.2   # Lasso alpha (acts like lambda)
nEnsembles = 100
ensembleT = 0.6      # threshold on inclusion probability

# Lorenz parameters and initial condition
sigma_l, rho_l, beta_l = 10.0, 28.0, 8.0/3.0
ode_params = (sigma_l, rho_l, beta_l)
x0 = np.array([-8.0, 8.0, 27.0])
dt = 0.01

rng = np.random.default_rng(1)

# -----------------------
# helper functions
# -----------------------
def lorenz(t, x, params):
    s, r, b = params
    dx = np.empty_like(x)
    dx[0] = s * (x[1] - x[0])
    dx[1] = x[0] * (r - x[2]) - x[1]
    dx[2] = x[0] * x[1] - b * x[2]
    return dx

def build_theta(X, polys=(1,2)):
    # X shape: (n_time, n_state)  -> build library rows per time
    # library: constant, x, y, z, x^2, xy, xz, y^2, yz, z^2  for polys up to 2
    nT, nState = X.shape
    assert nState == 3
    x = X[:,0]; y = X[:,1]; z = X[:,2]
    cols = [np.ones(nT), x, y, z]
    if 2 in polys:
        cols += [x**2, x*y, x*z, y**2, y*z, z**2]
    Theta = np.vstack(cols).T  # (nT, nFeatures)
    return Theta

def central_diff_matrix(n, dt):
    # returns matrix D of shape (n, n) that approximates d/dt via 2nd-order central diff with one-sided ends
    D = np.zeros((n, n))
    if n < 4:
        # fallback to simple diff
        for i in range(n-1):
            D[i,i] = -1.0/dt; D[i,i+1] = 1.0/dt
        D[n-1, n-2] = -1.0/dt; D[n-1, n-1] = 1.0/dt
        return D
    # first point: forward-biased 3rd order
    D[0,0] = -11/6; D[0,1]=3; D[0,2]=-1.5; D[0,3]=1/3
    D[0,:] /= dt
    # interior central
    for i in range(1,n-1):
        D[i,i-1] = -0.5; D[i,i+1] = 0.5
        D[i,:] /= dt
    # last point: backward-biased 3rd order
    D[-1,-1] = 11/6; D[-1,-2] = -3; D[-1,-3] = 1.5; D[-1,-4] = -1/3
    D[-1,:] /= dt
    return D

def fit_sindy_lasso(Theta, dX, alpha=lambda_alpha, max_iter=5000):
    # Fit Lasso separately for each state equation (columns of dX)
    # Theta: (nT, nFeat) ; dX: (nT, nState)
    nFeat = Theta.shape[1]
    nState = dX.shape[1]
    Xi = np.zeros((nFeat, nState))
    model = Lasso(alpha=alpha, fit_intercept=False, max_iter=max_iter)
    for j in range(nState):
        model.fit(Theta, dX[:, j])
        Xi[:, j] = model.coef_
    return Xi

# -----------------------
# compute "true" weights from noise-free integration (acts like getTrueWeights)
# -----------------------
t_full = np.arange(dt, 10.0 + dt/2, dt)
sol = solve_ivp(lambda t, y: lorenz(t, y, ode_params), (t_full[0], t_full[-1]), x0, t_eval=t_full, rtol=1e-10, atol=1e-10)
X_true = sol.y.T            # (nT, 3)
D = central_diff_matrix(X_true.shape[0], dt)
dX_true = D @ X_true        # approximate derivatives
Theta_true = build_theta(X_true, polys=(1,2))
# true weights via least-squares (pseudo-inverse)
true_nz_weights = np.linalg.lstsq(Theta_true, dX_true, rcond=None)[0]  # shape (nFeat, 3)

signal_power = np.std(X_true)

# -----------------------
# storage arrays
# -----------------------
n_eps = len(epsL); n_tend = len(tEndL)
nWrongTermsS = np.zeros((n_eps, n_tend, nTest1), dtype=int)
modelErrorS = np.zeros_like(nWrongTermsS, dtype=float)
successS = np.zeros_like(nWrongTermsS, dtype=bool)

nWrongTermsE = np.zeros((n_eps, n_tend, nTest2), dtype=int)
modelErrorE = np.zeros_like(nWrongTermsE, dtype=float)
successE = np.zeros_like(nWrongTermsE, dtype=bool)

# -----------------------
# Main loops
# -----------------------
print("Starting simulation loops...")
for ieps in range(n_eps):
    noise_ratio = epsL[ieps]
    for idt in range(n_tend):
        tEnd = float(tEndL[idt])
        tspan = np.arange(dt, tEnd + dt/2, dt)
        sol = solve_ivp(lambda t, y: lorenz(t, y, ode_params), (tspan[0], tspan[-1]), x0, t_eval=tspan, rtol=1e-10, atol=1e-10)
        X = sol.y.T  # (nT, 3)
        # set reproducible RNG for each loop similar to rng(1,'twister')
        local_rng = np.random.default_rng(1)

        # ----- SINDy single-run experiments -----
        for ii in range(nTest1):
            sigma = noise_ratio * signal_power
            noise = local_rng.normal(0.0, sigma, size=X.shape)
            Xobs = X + noise
            Theta_0 = build_theta(Xobs, polys=(1,2))
            Dmat = central_diff_matrix(Xobs.shape[0], dt)
            dXobs = Dmat @ Xobs
            Xi_hat = fit_sindy_lasso(Theta_0, dXobs, alpha=lambda_alpha)
            # metrics
            nz_true = (np.abs(true_nz_weights) > 1e-12).astype(int)
            nz_hat = (np.abs(Xi_hat) > 1e-12).astype(int)
            nWrongTermsS[ieps, idt, ii] = np.sum(np.abs(nz_true - nz_hat))
            modelErrorS[ieps, idt, ii] = np.linalg.norm(Xi_hat - true_nz_weights, ord='fro') / np.linalg.norm(true_nz_weights, ord='fro')
            successS[ieps, idt, ii] = int(np.sum(np.abs(nz_true - nz_hat)) == 0)

        # ----- Ensemble experiments (bootstrap on data) -----
        for ii in range(nTest2):
            sigma = noise_ratio * signal_power
            noise = local_rng.normal(0.0, sigma, size=X.shape)
            Xobs = X + noise
            Theta_0 = build_theta(Xobs, polys=(1,2))
            Dmat = central_diff_matrix(Xobs.shape[0], dt)
            dXobs = Dmat @ Xobs

            # bootstrap ensemble: sample with replacement along time indices
            nT = Theta_0.shape[0]
            Xi_ensembles = np.zeros((Theta_0.shape[1], Xobs.shape[1], nEnsembles))
            nz_ensembles = np.zeros_like(Xi_ensembles, dtype=int)
            for e in range(nEnsembles):
                idx = local_rng.integers(0, nT, size=nT)  # bootstrap indices
                Theta_bs = Theta_0[idx, :]
                dX_bs = dXobs[idx, :]
                Xi_e = fit_sindy_lasso(Theta_bs, dX_bs, alpha=lambda_alpha)
                Xi_ensembles[:, :, e] = Xi_e
                nz_ensembles[:, :, e] = (np.abs(Xi_e) > 1e-12).astype(int)

            # inclusion probability per coefficient
            incl_prob = nz_ensembles.mean(axis=2)  # (nFeat, nState)
            mask = (incl_prob >= ensembleT)

            Xi_mean = Xi_ensembles.mean(axis=2)
            Xi_median = np.median(Xi_ensembles, axis=2)

            # threshold small-prob coeffs to zero
            Xi_mean[~mask] = 0.0
            Xi_median[~mask] = 0.0

            # choose median as ensemble estimator (like XiMedian in MATLAB)
            Xi_est = Xi_median

            nz_true = (np.abs(true_nz_weights) > 1e-12).astype(int)
            nz_hat = (np.abs(Xi_est) > 1e-12).astype(int)
            nWrongTermsE[ieps, idt, ii] = np.sum(np.abs(nz_true - nz_hat))
            modelErrorE[ieps, idt, ii] = np.linalg.norm(Xi_est - true_nz_weights, ord='fro') / np.linalg.norm(true_nz_weights, ord='fro')
            successE[ieps, idt, ii] = int(np.sum(np.abs(nz_true - nz_hat)) == 0)

        print(f"eps idx {ieps+1}/{n_eps}, tEnd idx {idt+1}/{n_tend}")

# -----------------------
# Save results
# -----------------------
outdir = "results_py"
os.makedirs(outdir, exist_ok=True)
np.savez(os.path.join(outdir, "Lorenz_simOutS_MWE.npz"),
         nWrongTermsS=nWrongTermsS, modelErrorS=modelErrorS, successS=successS,
         epsL=epsL, tEndL=tEndL)
np.savez(os.path.join(outdir, "Lorenz_simOutE_MWE.npz"),
         nWrongTermsE=nWrongTermsE, modelErrorE=modelErrorE, successE=successE,
         epsL=epsL, tEndL=tEndL)

print("Done. Results saved to 'results_py/'")
# Out:
# Starting simulation loops...
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.799e+02, tolerance: 1.225e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.876e+02, tolerance: 3.127e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.412e+02, tolerance: 2.536e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.488e+03, tolerance: 2.430e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.751e+02, tolerance: 3.203e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.067e+02, tolerance: 3.036e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.656e+03, tolerance: 3.174e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.972e+02, tolerance: 1.003e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.455e+02, tolerance: 1.191e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.076e+02, tolerance: 2.054e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.368e+02, tolerance: 1.508e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.695e+02, tolerance: 2.351e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.319e+02, tolerance: 2.285e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.171e+02, tolerance: 1.328e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.567e+02, tolerance: 1.920e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.654e+02, tolerance: 2.182e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.705e+03, tolerance: 1.486e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.806e+02, tolerance: 2.133e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.985e+02, tolerance: 1.217e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.684e+02, tolerance: 1.386e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.875e+02, tolerance: 2.198e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.181e+02, tolerance: 1.169e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.118e+02, tolerance: 2.360e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.408e+02, tolerance: 2.062e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.325e+02, tolerance: 1.113e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.095e+02, tolerance: 1.174e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.259e+02, tolerance: 1.259e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.508e+02, tolerance: 2.751e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.913e+02, tolerance: 2.554e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.175e+03, tolerance: 1.033e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.110e+02, tolerance: 2.031e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.110e+02, tolerance: 2.069e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.295e+03, tolerance: 2.511e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.537e+02, tolerance: 1.462e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.584e+02, tolerance: 2.329e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.381e+02, tolerance: 1.445e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.091e+02, tolerance: 2.078e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.853e+03, tolerance: 2.480e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.310e+02, tolerance: 1.230e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.474e+02, tolerance: 2.283e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.064e+02, tolerance: 1.382e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.299e+02, tolerance: 1.109e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.850e+02, tolerance: 1.475e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.590e+02, tolerance: 1.547e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.504e+02, tolerance: 1.542e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.239e+02, tolerance: 2.287e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.849e+02, tolerance: 1.391e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.167e+02, tolerance: 1.144e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.570e+02, tolerance: 1.127e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.330e+02, tolerance: 2.281e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.042e+02, tolerance: 1.827e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.051e+02, tolerance: 1.389e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.382e+02, tolerance: 2.253e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.266e+02, tolerance: 1.169e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.686e+02, tolerance: 2.085e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.617e+02, tolerance: 1.359e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.601e+02, tolerance: 3.118e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.037e+03, tolerance: 2.789e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.507e+02, tolerance: 3.191e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.940e+02, tolerance: 2.857e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.796e+03, tolerance: 3.020e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.007e+02, tolerance: 1.180e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.088e+02, tolerance: 2.656e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.410e+02, tolerance: 2.208e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.908e+03, tolerance: 3.349e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.139e+03, tolerance: 3.029e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.444e+03, tolerance: 2.793e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.203e+03, tolerance: 3.033e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.845e+02, tolerance: 2.956e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.618e+02, tolerance: 3.251e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.300e+03, tolerance: 3.248e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.203e+03, tolerance: 3.341e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.002e+02, tolerance: 1.178e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.829e+02, tolerance: 3.386e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.359e+02, tolerance: 3.734e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.632e+02, tolerance: 1.076e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.290e+02, tolerance: 2.759e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.299e+02, tolerance: 2.660e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.381e+02, tolerance: 1.016e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.060e+02, tolerance: 2.952e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.195e+03, tolerance: 3.413e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.495e+02, tolerance: 3.425e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.155e+03, tolerance: 2.945e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.050e+03, tolerance: 3.323e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.240e+02, tolerance: 2.914e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.267e+02, tolerance: 3.557e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.296e+03, tolerance: 2.975e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.182e+02, tolerance: 1.173e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.795e+02, tolerance: 3.269e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.183e+02, tolerance: 2.879e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.296e+02, tolerance: 1.191e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.593e+03, tolerance: 2.738e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.856e+03, tolerance: 2.846e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.327e+03, tolerance: 3.392e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.463e+02, tolerance: 9.595e+01
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.851e+02, tolerance: 3.091e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.586e+03, tolerance: 3.005e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.449e+02, tolerance: 3.103e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.599e+02, tolerance: 1.102e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.584e+02, tolerance: 3.148e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.842e+02, tolerance: 1.059e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.672e+02, tolerance: 3.124e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.850e+02, tolerance: 1.101e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.687e+03, tolerance: 3.205e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.116e+03, tolerance: 2.070e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.675e+03, tolerance: 2.048e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.740e+02, tolerance: 2.161e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.172e+02, tolerance: 2.101e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.963e+03, tolerance: 2.450e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.324e+03, tolerance: 2.343e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.213e+03, tolerance: 2.233e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.102e+02, tolerance: 3.193e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.302e+03, tolerance: 1.920e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.008e+03, tolerance: 2.853e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.134e+03, tolerance: 2.058e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.972e+02, tolerance: 2.149e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.201e+03, tolerance: 1.926e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.241e+02, tolerance: 2.084e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.472e+02, tolerance: 1.936e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.002e+03, tolerance: 2.981e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.783e+03, tolerance: 1.893e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.118e+02, tolerance: 2.142e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.525e+03, tolerance: 1.820e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.522e+02, tolerance: 3.103e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.747e+03, tolerance: 2.368e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.711e+03, tolerance: 3.106e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.044e+03, tolerance: 1.966e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.393e+03, tolerance: 1.906e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.104e+02, tolerance: 1.983e+02
#   model = cd_fast.enet_coordinate_descent(
# ...
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.241e+03, tolerance: 3.217e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.706e+02, tolerance: 2.137e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.981e+02, tolerance: 1.976e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.778e+02, tolerance: 2.295e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.215e+02, tolerance: 2.088e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.906e+02, tolerance: 2.555e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.055e+03, tolerance: 2.253e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.319e+02, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.503e+02, tolerance: 2.551e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.727e+02, tolerance: 2.194e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.260e+02, tolerance: 2.178e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.822e+02, tolerance: 2.066e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.129e+03, tolerance: 2.078e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.703e+02, tolerance: 3.030e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.692e+02, tolerance: 2.507e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.194e+02, tolerance: 2.447e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.115e+03, tolerance: 2.582e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.557e+03, tolerance: 2.333e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.970e+03, tolerance: 2.367e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.392e+03, tolerance: 2.669e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.898e+02, tolerance: 2.491e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.656e+02, tolerance: 2.275e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.759e+02, tolerance: 2.556e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.657e+03, tolerance: 2.247e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.545e+02, tolerance: 2.250e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.577e+02, tolerance: 2.576e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.815e+02, tolerance: 1.202e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.778e+02, tolerance: 1.098e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.833e+02, tolerance: 1.166e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.140e+02, tolerance: 3.043e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.835e+02, tolerance: 1.014e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/grisal/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.869e+02, tolerance: 1.070e+02
#   model = cd_fast.enet_coordinate_descent(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 168
#     166 Theta_bs = Theta_0[idx, :]
#     167 dX_bs = dXobs[idx, :]
# --> 168 Xi_e = fit_sindy_lasso(Theta_bs, dX_bs, alpha=lambda_alpha)
#     169 Xi_ensembles[:, :, e] = Xi_e
#     170 nz_ensembles[:, :, e] = (np.abs(Xi_e) > 1e-12).astype(int)
#
# Cell In[29], line 91, in fit_sindy_lasso(Theta, dX, alpha, max_iter)
#      89 model = Lasso(alpha=alpha, fit_intercept=False, max_iter=max_iter)
#      90 for j in range(nState):
# ---> 91     model.fit(Theta, dX[:, j])
#      92     Xi[:, j] = model.coef_
#      93 return Xi
#
# File ~/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:1084, in ElasticNet.fit(self, X, y, sample_weight, check_input)
#    1082 else:
#    1083     this_Xy = None
# -> 1084 _, this_coef, this_dual_gap, this_iter = self.path(
#    1085     X,
#    1086     y[:, k],
#    1087     l1_ratio=self.l1_ratio,
#    1088     eps=None,
#    1089     n_alphas=None,
#    1090     alphas=[alpha],
#    1091     precompute=precompute,
#    1092     Xy=this_Xy,
#    1093     copy_X=True,
#    1094     coef_init=coef_[k],
#    1095     verbose=False,
#    1096     return_n_iter=True,
#    1097     positive=self.positive,
#    1098     check_input=False,
#    1099     # from here on **params
#    1100     tol=self.tol,
#    1101     X_offset=X_offset,
#    1102     X_scale=X_scale,
#    1103     max_iter=self.max_iter,
#    1104     random_state=self.random_state,
#    1105     selection=self.selection,
#    1106     sample_weight=sample_weight,
#    1107 )
#    1108 coef_[k] = this_coef[:, 0]
#    1109 dual_gaps_[k] = this_dual_gap[0]
#
# File ~/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File ~/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695, in enet_path(X, y, l1_ratio, eps, n_alphas, alphas, precompute, Xy, copy_X, coef_init, verbose, return_n_iter, positive, check_input, **params)
#     681     model = cd_fast.enet_coordinate_descent_gram(
#     682         coef_,
#     683         l1_reg,
#    (...)    692         positive,
#     693     )
#     694 elif precompute is False:
# --> 695     model = cd_fast.enet_coordinate_descent(
#     696         coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
#     697     )
#     698 else:
#     699     raise ValueError(
#     700         "Precompute should be one of True, False, 'auto' or array-like. Got %r"
#     701         % precompute
#     702     )
#
# File ~/github/jsindy/.venv/lib/python3.12/site-packages/sklearn/linear_model/_cd_fast.pyx:142, in sklearn.linear_model._cd_fast.enet_coordinate_descent()
#
# File ~/github/jsindy/.venv/lib/python3.12/site-packages/numpy/_core/_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      45 def _amin(a, axis=None, out=None, keepdims=False,
#      46           initial=_NoValue, where=True):
#      47     return umr_minimum(a, axis, None, out, keepdims, initial, where)
# ---> 49 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      50          initial=_NoValue, where=True):
#      51     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      53 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#      54           initial=_NoValue, where=True):
#
# KeyboardInterrupt:
